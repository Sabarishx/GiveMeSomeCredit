# %%
import pandas as pd
import numpy as np

# %%
df = pd.read_csv(r'C:\Users\sabar\OneDrive\Documents\AI_ML\Credit Risk Analytics\GiveMeSomeCredit\cs-training.csv').drop(columns=['Unnamed: 0'], axis=1)

# %%
df.head()
# Out:
#    SeriousDlqin2yrs  RevolvingUtilizationOfUnsecuredLines  age  \
# 0                 1                              0.766127   45
# 1                 0                              0.957151   40
# 2                 0                              0.658180   38
# 3                 0                              0.233810   30
# 4                 0                              0.907239   49
#
#    NumberOfTime30-59DaysPastDueNotWorse  DebtRatio  MonthlyIncome  \
# 0                                     2   0.802982         9120.0
# 1                                     0   0.121876         2600.0
# 2                                     1   0.085113         3042.0
# 3                                     0   0.036050         3300.0
# 4                                     1   0.024926        63588.0
#
#    NumberOfOpenCreditLinesAndLoans  NumberOfTimes90DaysLate  \
# 0                               13                        0
# 1                                4                        0
# ...

# %%
df.shape
# Out:
# (150000, 11)

# %%
df.describe()
# Out:
#        SeriousDlqin2yrs  RevolvingUtilizationOfUnsecuredLines            age  \
# count     150000.000000                         150000.000000  150000.000000
# mean           0.066840                              6.048438      52.295207
# std            0.249746                            249.755371      14.771866
# min            0.000000                              0.000000       0.000000
# 25%            0.000000                              0.029867      41.000000
# 50%            0.000000                              0.154181      52.000000
# 75%            0.000000                              0.559046      63.000000
# max            1.000000                          50708.000000     109.000000
#
#        NumberOfTime30-59DaysPastDueNotWorse      DebtRatio  MonthlyIncome  \
# count                         150000.000000  150000.000000   1.202690e+05
# mean                               0.421033     353.005076   6.670221e+03
# ...

# %%
missing_data = (df.isnull().sum()/len(df))*100

# %%
missing_data
# Out:
# SeriousDlqin2yrs                         0.000000
# RevolvingUtilizationOfUnsecuredLines     0.000000
# age                                      0.000000
# NumberOfTime30-59DaysPastDueNotWorse     0.000000
# DebtRatio                                0.000000
# MonthlyIncome                           19.820667
# NumberOfOpenCreditLinesAndLoans          0.000000
# NumberOfTimes90DaysLate                  0.000000
# NumberRealEstateLoansOrLines             0.000000
# NumberOfTime60-89DaysPastDueNotWorse     0.000000
# NumberOfDependents                       2.616000
# dtype: float64

# %%
missing_data = (df.isnull().sum()/len(df))*100

threshold = 70

columns_to_drop = missing_data[missing_data>= threshold].index.to_list()


if columns_to_drop:
    print(f'columns to be dropped{columns_to_drop}')
    df=df.drop(columns=columns_to_drop, axis=1)
else:
    print('Missing data havent exceed 30%')
# Out:
# Missing data havent exceed 30%

# %%
df.shape
# Out:
# (150000, 11)

# %%
df.columns=df.columns.str.lower()

# %%
df.head()
# Out:
#    seriousdlqin2yrs  revolvingutilizationofunsecuredlines  age  \
# 0                 1                              0.766127   45
# 1                 0                              0.957151   40
# 2                 0                              0.658180   38
# 3                 0                              0.233810   30
# 4                 0                              0.907239   49
#
#    numberoftime30-59dayspastduenotworse  debtratio  monthlyincome  \
# 0                                     2   0.802982         9120.0
# 1                                     0   0.121876         2600.0
# 2                                     1   0.085113         3042.0
# 3                                     0   0.036050         3300.0
# 4                                     1   0.024926        63588.0
#
#    numberofopencreditlinesandloans  numberoftimes90dayslate  \
# 0                               13                        0
# 1                                4                        0
# ...

# %%
df['monthlyincome']=df['monthlyincome'].fillna(df['monthlyincome'].mean())
df['numberofdependents'].fillna(df['numberofdependents'].mean(), inplace=True)

# %%
missing_data
# Out:
# SeriousDlqin2yrs                         0.000000
# RevolvingUtilizationOfUnsecuredLines     0.000000
# age                                      0.000000
# NumberOfTime30-59DaysPastDueNotWorse     0.000000
# DebtRatio                                0.000000
# MonthlyIncome                           19.820667
# NumberOfOpenCreditLinesAndLoans          0.000000
# NumberOfTimes90DaysLate                  0.000000
# NumberRealEstateLoansOrLines             0.000000
# NumberOfTime60-89DaysPastDueNotWorse     0.000000
# NumberOfDependents                       2.616000
# dtype: float64

# %%
df['age']

pd.set_option('display.max_rows', 20)

# %%
cleaned_df = df[(df['age'] >= 17) & (df['age'] <= 80)]

# %%
cleaned_df
# Out:
#         seriousdlqin2yrs  revolvingutilizationofunsecuredlines  age  \
# 0                      1                              0.766127   45
# 1                      0                              0.957151   40
# 2                      0                              0.658180   38
# 3                      0                              0.233810   30
# 4                      0                              0.907239   49
# ...                  ...                                   ...  ...
# 149995                 0                              0.040674   74
# 149996                 0                              0.299745   44
# 149997                 0                              0.246044   58
# 149998                 0                              0.000000   30
# 149999                 0                              0.850283   64
#
#         numberoftime30-59dayspastduenotworse    debtratio  monthlyincome  \
# 0                                          2     0.802982    9120.000000
# ...

# %%
mis_data = (df.isnull().sum()/len(df))
mis_data

threshold = 30

data_dropped = mis_data[mis_data >= threshold].index.to_list()

if data_dropped:
    print(f'Columns to be dropped {data_dropped}')
    df.drop(colums=data_dropped, axis=1)
else:
    print(f'Missing values havent exeed {threshold}%')
# Out:
# Missing values havent exeed 30%
